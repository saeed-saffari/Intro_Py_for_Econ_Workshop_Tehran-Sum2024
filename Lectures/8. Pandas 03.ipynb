# %% [markdown]
# # <center> Pandas (part 03) <center>

# %% [markdown]
# <img src = 'https://github.com/saeed-saffari/alzahra-workshop-spr2021/blob/main/lecture/PIC/Pandas.png?raw=true'
#      width = "550"
#      >

# %% [markdown]
# ##  <center> Working with Real data

# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# %% [markdown]
# ### 1. from Excel, CSV, ...

# %%
os.listdir()
# Out:
# ['time_series_covid19_confirmed_global.csv',
#  '5. Matplotlib.ipynb',
#  'survey_results_public.csv',
#  'world-happiness-report-2021.csv',
#  '.DS_Store',
#  'P_Data_Extract_From_World_Development_Indicators.xlsx',
#  'Project 01 - Covid19 confirmed cases.ipynb',
#  'Iran_gdp_growth.jpg',
#  '~$P_Data_Extract_From_World_Development_Indicators.xlsx',
#  '1. Introduction to Python (Data Structure).ipynb',
#  'GDP per capita ppp 2021.xlsx',
#  'Real GDP Growth (IMF).xlsx',
#  '3. Functions.ipynb',
#  'Py for Econ-Intro-Tehran Workshop 2024.pdf',
#  '6. Pandas 01.ipynb',
#  '2. Control flow (Loops).ipynb',
#  '7. Pandas 02.ipynb',
#  'Human development index (HDI).xlsx',
#  '.ipynb_checkpoints',
#  'test_1.jpg',
#  'data',
#  '8. Pandas 03.ipynb',
#  '4. NumPy.ipynb']

# %%
gdp = pd.read_excel('P_Data_Extract_From_World_Development_Indicators.xlsx')
gdp.head()
# Out:
#          Series Name     Series Code    Country Name Country Code  \
# 0  GDP (current US$)  NY.GDP.MKTP.CD     Afghanistan          AFG
# 1  GDP (current US$)  NY.GDP.MKTP.CD         Albania          ALB
# 2  GDP (current US$)  NY.GDP.MKTP.CD         Algeria          DZA
# 3  GDP (current US$)  NY.GDP.MKTP.CD  American Samoa          ASM
# 4  GDP (current US$)  NY.GDP.MKTP.CD         Andorra          AND
#
#        1960 [YR1960]      1961 [YR1961]      1962 [YR1962]      1963 [YR1963]  \
# 0                 ..                 ..                 ..                 ..
# 1                 ..                 ..                 ..                 ..
# 2  2723615451.300977  2434747055.940175  2001444543.918851  2702982017.638028
# 3                 ..                 ..                 ..                 ..
# 4                 ..                 ..                 ..                 ..
#
#        1964 [YR1964]      1965 [YR1965]  ...        2014 [YR2014]  \
# ...

# %%
gdp.tail(10)
# Out:
#                                           Series Name     Series Code  \
# 261                                 GDP (current US$)  NY.GDP.MKTP.CD
# 262                                 GDP (current US$)  NY.GDP.MKTP.CD
# 263                                 GDP (current US$)  NY.GDP.MKTP.CD
# 264                                 GDP (current US$)  NY.GDP.MKTP.CD
# 265                                 GDP (current US$)  NY.GDP.MKTP.CD
# 266                                               NaN             NaN
# 267                                               NaN             NaN
# 268                                               NaN             NaN
# 269  Data from database: World Development Indicators             NaN
# 270                          Last Updated: 06/28/2024             NaN
#
#                                    Country Name Country Code  \
# 261                          Sub-Saharan Africa          SSF
# 262  Sub-Saharan Africa (excluding high income)          SSA
# ...

# %% [markdown]
# ### 1.2 drop useless data

# %% [markdown]
# #### 1.2.1 drop indeces

# %%
np.arange(266,271)
# Out:
# array([266, 267, 268, 269, 270])

# %%
gdp.drop(np.arange(266,271), axis = 0, inplace=True)
gdp.tail()
# Out:
#            Series Name     Series Code  \
# 261  GDP (current US$)  NY.GDP.MKTP.CD
# 262  GDP (current US$)  NY.GDP.MKTP.CD
# 263  GDP (current US$)  NY.GDP.MKTP.CD
# 264  GDP (current US$)  NY.GDP.MKTP.CD
# 265  GDP (current US$)  NY.GDP.MKTP.CD
#
#                                    Country Name Country Code  \
# 261                          Sub-Saharan Africa          SSF
# 262  Sub-Saharan Africa (excluding high income)          SSA
# 263   Sub-Saharan Africa (IDA & IBRD countries)          TSS
# 264                         Upper middle income          UMC
# 265                                       World          WLD
#
#             1960 [YR1960]         1961 [YR1961]         1962 [YR1962]  \
# 261    33100575536.151871    34987537580.418716     37301164846.12886
# 262    33090214943.754162    34977868084.024193    37290528805.263786
# 263    33100575536.151909    34987537580.418755    37301164846.128906
# 264   180053390475.166992   168982532613.972595   170141004179.807587
# ...

# %% [markdown]
# #### 1.2.2 drop columns

# %%
gdp.columns
# Out:
# Index(['Series Name', 'Series Code', 'Country Name', 'Country Code',
#        '1960 [YR1960]', '1961 [YR1961]', '1962 [YR1962]', '1963 [YR1963]',
#        '1964 [YR1964]', '1965 [YR1965]', '1966 [YR1966]', '1967 [YR1967]',
#        '1968 [YR1968]', '1969 [YR1969]', '1970 [YR1970]', '1971 [YR1971]',
#        '1972 [YR1972]', '1973 [YR1973]', '1974 [YR1974]', '1975 [YR1975]',
#        '1976 [YR1976]', '1977 [YR1977]', '1978 [YR1978]', '1979 [YR1979]',
#        '1980 [YR1980]', '1981 [YR1981]', '1982 [YR1982]', '1983 [YR1983]',
#        '1984 [YR1984]', '1985 [YR1985]', '1986 [YR1986]', '1987 [YR1987]',
#        '1988 [YR1988]', '1989 [YR1989]', '1990 [YR1990]', '1991 [YR1991]',
#        '1992 [YR1992]', '1993 [YR1993]', '1994 [YR1994]', '1995 [YR1995]',
#        '1996 [YR1996]', '1997 [YR1997]', '1998 [YR1998]', '1999 [YR1999]',
#        '2000 [YR2000]', '2001 [YR2001]', '2002 [YR2002]', '2003 [YR2003]',
#        '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]', '2007 [YR2007]',
# ...

# %%
gdp = gdp.drop(['Series Name', 'Series Code', 'Country Name'], axis = 1)
gdp.head()
# Out:
#   Country Code      1960 [YR1960]      1961 [YR1961]      1962 [YR1962]  \
# 0          AFG                 ..                 ..                 ..
# 1          ALB                 ..                 ..                 ..
# 2          DZA  2723615451.300977  2434747055.940175  2001444543.918851
# 3          ASM                 ..                 ..                 ..
# 4          AND                 ..                 ..                 ..
#
#        1963 [YR1963]      1964 [YR1964]      1965 [YR1965]      1966 [YR1966]  \
# 0                 ..                 ..                 ..                 ..
# 1                 ..                 ..                 ..                 ..
# 2  2702982017.638028  2909316435.287398  3136284306.854687  3039859187.451642
# 3                 ..                 ..                 ..                 ..
# 4                 ..                 ..                 ..                 ..
#
# ...

# %% [markdown]
# ### 1.3 change index

# %%
gdp.index
# Out:
# RangeIndex(start=0, stop=266, step=1)

# %%
gdp.set_index('Country Code', inplace=True)
gdp.head()
# Out:
#                   1960 [YR1960]      1961 [YR1961]      1962 [YR1962]  \
# Country Code
# AFG                          ..                 ..                 ..
# ALB                          ..                 ..                 ..
# DZA           2723615451.300977  2434747055.940175  2001444543.918851
# ASM                          ..                 ..                 ..
# AND                          ..                 ..                 ..
#
#                   1963 [YR1963]      1964 [YR1964]      1965 [YR1965]  \
# Country Code
# AFG                          ..                 ..                 ..
# ALB                          ..                 ..                 ..
# DZA           2702982017.638028  2909316435.287398  3136284306.854687
# ASM                          ..                 ..                 ..
# AND                          ..                 ..                 ..
#
#                   1966 [YR1966]      1967 [YR1967]      1968 [YR1968]  \
# Country Code
# ...

# %%
gdp.index
# Out:
# Index(['AFG', 'ALB', 'DZA', 'ASM', 'AND', 'AGO', 'ATG', 'ARG', 'ARM', 'ABW',
#        ...
#        'PST', 'PRE', 'SST', 'SAS', 'TSA', 'SSF', 'SSA', 'TSS', 'UMC', 'WLD'],
#       dtype='object', name='Country Code', length=266)

# %%
gdp.columns
# Out:
# Index(['1960 [YR1960]', '1961 [YR1961]', '1962 [YR1962]', '1963 [YR1963]',
#        '1964 [YR1964]', '1965 [YR1965]', '1966 [YR1966]', '1967 [YR1967]',
#        '1968 [YR1968]', '1969 [YR1969]', '1970 [YR1970]', '1971 [YR1971]',
#        '1972 [YR1972]', '1973 [YR1973]', '1974 [YR1974]', '1975 [YR1975]',
#        '1976 [YR1976]', '1977 [YR1977]', '1978 [YR1978]', '1979 [YR1979]',
#        '1980 [YR1980]', '1981 [YR1981]', '1982 [YR1982]', '1983 [YR1983]',
#        '1984 [YR1984]', '1985 [YR1985]', '1986 [YR1986]', '1987 [YR1987]',
#        '1988 [YR1988]', '1989 [YR1989]', '1990 [YR1990]', '1991 [YR1991]',
#        '1992 [YR1992]', '1993 [YR1993]', '1994 [YR1994]', '1995 [YR1995]',
#        '1996 [YR1996]', '1997 [YR1997]', '1998 [YR1998]', '1999 [YR1999]',
#        '2000 [YR2000]', '2001 [YR2001]', '2002 [YR2002]', '2003 [YR2003]',
#        '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]', '2007 [YR2007]',
# ...

# %%
np.arange(1960, 2024)
# Out:
# array([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#        1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#        1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#        1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023])

# %%
gdp.columns = np.arange(1960, 2024)

# %%
gdp.head()
# Out:
#                            1960               1961               1962  \
# Country Code
# AFG                          ..                 ..                 ..
# ALB                          ..                 ..                 ..
# DZA           2723615451.300977  2434747055.940175  2001444543.918851
# ASM                          ..                 ..                 ..
# AND                          ..                 ..                 ..
#
#                            1963               1964               1965  \
# Country Code
# AFG                          ..                 ..                 ..
# ALB                          ..                 ..                 ..
# DZA           2702982017.638028  2909316435.287398  3136284306.854687
# ASM                          ..                 ..                 ..
# AND                          ..                 ..                 ..
#
#                            1966               1967               1968  \
# Country Code
# ...

# %%
gdp.columns
# Out:
# Int64Index([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#             1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#             1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#             1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#             2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#             2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
#            dtype='int64')

# %%
gdp.shape
# Out:
# (266, 64)

# %% [markdown]
# ### 1.5 NaN data

# %%
gdp.head()
# Out:
#                            1960               1961               1962  \
# Country Code
# AFG                          ..                 ..                 ..
# ALB                          ..                 ..                 ..
# DZA           2723615451.300977  2434747055.940175  2001444543.918851
# ASM                          ..                 ..                 ..
# AND                          ..                 ..                 ..
#
#                            1963               1964               1965  \
# Country Code
# AFG                          ..                 ..                 ..
# ALB                          ..                 ..                 ..
# DZA           2702982017.638028  2909316435.287398  3136284306.854687
# ASM                          ..                 ..                 ..
# AND                          ..                 ..                 ..
#
#                            1966               1967               1968  \
# Country Code
# ...

# %%
gdp.iloc[0,0]
# Out:
# '..'

# %%
gdp.replace('..', np.nan, inplace=True)
gdp.head()
# Out:
#                       1960          1961          1962          1963  \
# Country Code
# AFG                    NaN           NaN           NaN           NaN
# ALB                    NaN           NaN           NaN           NaN
# DZA           2.723615e+09  2.434747e+09  2.001445e+09  2.702982e+09
# ASM                    NaN           NaN           NaN           NaN
# AND                    NaN           NaN           NaN           NaN
#
#                       1964          1965          1966          1967  \
# Country Code
# AFG                    NaN           NaN           NaN           NaN
# ALB                    NaN           NaN           NaN           NaN
# DZA           2.909316e+09  3.136284e+09  3.039859e+09  3.370870e+09
# ASM                    NaN           NaN           NaN           NaN
# AND                    NaN           NaN           NaN           NaN
#
#                       1968          1969  ...          2014          2015  \
# ...

# %% [markdown]
# ### 1.6 Transpose

# %%
gdp2 = gdp.T
gdp2.head()
# Out:
# Country Code  AFG  ALB           DZA  ASM  AND  AGO  ATG  ARG  ARM  ABW  ...  \
# 1960          NaN  NaN  2.723615e+09  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 1961          NaN  NaN  2.434747e+09  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 1962          NaN  NaN  2.001445e+09  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 1963          NaN  NaN  2.702982e+09  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 1964          NaN  NaN  2.909316e+09  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
#
# Country Code           PST           PRE  SST           SAS           TSA  \
# 1960          1.036275e+12  2.200996e+10  NaN  4.727433e+10  4.727433e+10
# 1961          1.103926e+12  2.333057e+10  NaN  5.046743e+10  5.046743e+10
# 1962          1.194312e+12  2.503997e+10  NaN  5.390576e+10  5.390576e+10
# 1963          1.285065e+12  2.656525e+10  NaN  6.049639e+10  6.049639e+10
# 1964          1.403989e+12  2.900430e+10  NaN  6.932009e+10  6.932009e+10
#
# ...

# %%
gdp2.columns
# Out:
# Index(['AFG', 'ALB', 'DZA', 'ASM', 'AND', 'AGO', 'ATG', 'ARG', 'ARM', 'ABW',
#        ...
#        'PST', 'PRE', 'SST', 'SAS', 'TSA', 'SSF', 'SSA', 'TSS', 'UMC', 'WLD'],
#       dtype='object', name='Country Code', length=266)

# %%
gdp2.index
# Out:
# Int64Index([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#             1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#             1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#             1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#             2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#             2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
#            dtype='int64')

# %%
gdp2.describe()
# Out:
# Country Code           AFG           ALB           DZA           ASM  \
# count         2.300000e+01  4.000000e+01  6.400000e+01  2.100000e+01
# mean          1.309344e+10  7.868635e+09  7.971057e+10  6.161429e+08
# std           6.418341e+09  6.072031e+09  7.622343e+10  9.567512e+07
# min           2.813572e+09  6.521750e+08  2.001445e+09  4.930000e+08
# 25%           6.587507e+09  2.214149e+09  1.718566e+10  5.240000e+08
# 50%           1.450216e+10  6.398091e+09  4.937348e+10  6.380000e+08
# 75%           1.877645e+10  1.280251e+10  1.444414e+11  6.710000e+08
# max           2.049713e+10  2.297768e+10  2.398995e+11  8.710000e+08
#
# Country Code           AND           AGO           ATG           ARG  \
# count         5.400000e+01  3.100000e+01  4.700000e+01  4.100000e+01
# mean          1.699461e+09  5.465405e+10  8.963700e+08  3.179862e+11
# std           1.347454e+09  4.266213e+10  5.599776e+08  1.784104e+11
# ...

# %%
gdp.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  1.380000e+02  1.420000e+02  1.440000e+02  1.440000e+02  1.440000e+02
# mean   7.203005e+10  7.346038e+10  7.713834e+10  8.350185e+10  9.215755e+10
# std    2.108081e+11  2.199103e+11  2.350450e+11  2.531822e+11  2.774464e+11
# min    1.201202e+07  1.159202e+07  9.122751e+06  1.084010e+07  1.271247e+07
# 25%    4.640236e+08  4.869202e+08  5.185977e+08  5.150864e+08  5.415796e+08
# 50%    2.742183e+09  2.630463e+09  2.597113e+09  3.079781e+09  3.184168e+09
# 75%    3.047209e+10  3.063881e+10  3.000765e+10  3.145128e+10  3.308114e+10
# max    1.364504e+12  1.439319e+12  1.542845e+12  1.664977e+12  1.827785e+12
#
#                1965          1966          1967          1968          1969  \
# count  1.540000e+02  1.550000e+02  1.580000e+02  1.590000e+02  1.590000e+02
# mean   9.452375e+10  1.009367e+11  1.049391e+11  1.121993e+11  1.240775e+11
# ...

# %% [markdown]
# ### 1.6 Plot

# %%
gdp2.head()
# Out:
# Country Code  AFG  ALB           DZA  ASM  AND  AGO  ATG  ARG  ARM  ABW  ...  \
# 1960          NaN  NaN  2.723615e+09  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 1961          NaN  NaN  2.434747e+09  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 1962          NaN  NaN  2.001445e+09  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 1963          NaN  NaN  2.702982e+09  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 1964          NaN  NaN  2.909316e+09  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
#
# Country Code           PST           PRE  SST           SAS           TSA  \
# 1960          1.036275e+12  2.200996e+10  NaN  4.727433e+10  4.727433e+10
# 1961          1.103926e+12  2.333057e+10  NaN  5.046743e+10  5.046743e+10
# 1962          1.194312e+12  2.503997e+10  NaN  5.390576e+10  5.390576e+10
# 1963          1.285065e+12  2.656525e+10  NaN  6.049639e+10  6.049639e+10
# 1964          1.403989e+12  2.900430e+10  NaN  6.932009e+10  6.932009e+10
#
# ...

# %%
gdp2.plot(y = ['IRN'], figsize = (12,7), lw = 3, c = 'g')

plt.grid()
plt.xlabel('Year', fontsize=14, fontname = "Times New Roman")
plt.ylabel('GDP (Trilion dollar)', fontsize=14, fontname = "Times New Roman")
plt.title("Iran's GDP current US$", fontsize=16, fontname = "Times New Roman")

plt.legend(loc = 'upper left', fontsize=10)


plt.show()

# %%
#pd.set_option('display.max_rows', None)
#pd.reset_option('display.max_rows')

# %%
gdp2['IRN']
# Out:
# 1960    4.199134e+09
# 1961    4.426949e+09
# 1962    4.693566e+09
# 1963    4.928628e+09
# 1964    5.379846e+09
#             ...
# 2019    2.836495e+11
# 2020    2.397355e+11
# 2021    3.590969e+11
# 2022    4.133946e+11
# 2023    4.015045e+11
# Name: IRN, Length: 64, dtype: float64

# %%
gdp2['IRN'] = gdp2['IRN'].interpolate()

# %%
gdp2.plot(y = ['IRN'], figsize = (12,7), lw = 3, c = 'g')

plt.grid()
plt.xlabel('Year', fontsize=14, fontname = "Times New Roman")
plt.ylabel('GDP (Trilion dollar)', fontsize=14, fontname = "Times New Roman")
plt.title("Iran's GDP current US$", fontsize=16, fontname = "Times New Roman")

plt.legend(loc = 'upper left', fontsize=10)


plt.show()

# %%
gdp2.plot(y = ['IRN', 'AUS', 'CAN', 'BRA'], figsize = (12,7), lw = 3)

plt.grid()
plt.xlabel('Year', fontsize=14, fontname = "Times New Roman")
plt.ylabel('GDP (Trilion dollar)', fontsize=14, fontname = "Times New Roman")
plt.title("GDP current US$", fontsize=16, fontname = "Times New Roman")

plt.legend(loc = 'upper left', fontsize=10)


plt.show()

# %% [markdown]
# ## 2. Online data

# %% [markdown]
# ### 2.1 Imports

# %%
import yfinance as yf
from pandas_datareader import data
import datetime as dt

# %%
start = dt.datetime(2024, 1, 2)
end = dt.date.today()

yf.pdr_override()
price = data.DataReader('GOOG', start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
price.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-02  139.600006  140.615005  137.740005  139.559998  139.401367
# 2024-01-03  138.600006  141.089996  138.429993  140.360001  140.200455
# 2024-01-04  139.850006  140.634995  138.009995  138.039993  137.883087
# 2024-01-05  138.352005  138.809998  136.850006  137.389999  137.233841
# 2024-01-08  138.000000  140.639999  137.880005  140.529999  140.370270
#
#               Volume
# Date
# 2024-01-02  20071900
# 2024-01-03  18974300
# 2024-01-04  18253300
# 2024-01-05  15433200
# 2024-01-08  17645300

# %%
price.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-08-01  171.979996  175.679993  170.509995  172.449997  172.449997
# 2024-08-02  168.190002  170.210007  166.389999  168.399994  168.399994
# 2024-08-05  157.369995  165.940002  156.600006  160.639999  160.639999
# 2024-08-06  160.945007  162.350006  158.130005  160.539993  160.539993
# 2024-08-07  163.240005  164.789993  160.240005  160.750000  160.750000
#
#               Volume
# Date
# 2024-08-01  17177800
# 2024-08-02  18907800
# 2024-08-05  34907800
# 2024-08-06  36146500
# 2024-08-07  19288800

# %%
price['Volume'].plot(figsize = (12,7), lw = 2)

plt.grid()
plt.xlabel('Date', fontsize=14, fontname = "Times New Roman")
plt.ylabel('Valume', fontsize=14, fontname = "Times New Roman")
plt.title("Valume timeline of Google", fontsize=16, fontname = "Times New Roman")

plt.legend(fontsize=10)

plt.show()

# %%
price[['Open', 'Close']].plot(figsize = (12,7), lw = 2)

plt.grid()
plt.xlabel('Date', fontsize=14, fontname = "Times New Roman")
plt.ylabel('Price', fontsize=14, fontname = "Times New Roman")
plt.title("Open and Close Price timeline of Google", fontsize=16, fontname = "Times New Roman")

plt.legend(fontsize=10)

plt.show()

# %%
price[['Open', 'Close']].plot(figsize = (12,7), lw = 2)

plt.grid()
plt.xlabel('Date', fontsize=14, fontname = "Times New Roman")
plt.ylabel('Price', fontsize=14, fontname = "Times New Roman")
plt.title("Open and Close Price timeline of Google", fontsize=16, fontname = "Times New Roman")

plt.legend(fontsize=10)

plt.xlim(('2024-02-07', '2024-05-07'))   # new

plt.show()

# %%
price.loc['2024-02-07':'2024-05-07', ['Open', 'Close']].plot(figsize = (12,7), lw = 2)

plt.grid()
plt.xlabel('Date', fontsize=14, fontname = "Times New Roman")
plt.ylabel('Price', fontsize=14, fontname = "Times New Roman")
plt.title("Open and Close Price timeline of Google", fontsize=16, fontname = "Times New Roman")

plt.legend(fontsize=10)

plt.show()

# %%
price2 = data.DataReader(['GOOG', 'AAPL'], start, end)
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
price2.head()
# Out:
#              Adj Close                   Close                    High  \
#                   AAPL        GOOG        AAPL        GOOG        AAPL
# Date
# 2024-01-02  185.152283  139.401367  185.639999  139.559998  188.440002
# 2024-01-03  183.765930  140.200455  184.250000  140.360001  185.880005
# 2024-01-04  181.432098  137.883087  181.910004  138.039993  183.089996
# 2024-01-05  180.703995  137.233841  181.179993  137.389999  182.759995
# 2024-01-08  185.072495  140.370270  185.559998  140.529999  185.600006
#
#                                Low                    Open              \
#                   GOOG        AAPL        GOOG        AAPL        GOOG
# Date
# 2024-01-02  140.615005  183.889999  137.740005  187.149994  139.600006
# 2024-01-03  141.089996  183.429993  138.429993  184.220001  138.600006
# 2024-01-04  140.634995  180.880005  138.009995  182.149994  139.850006
# 2024-01-05  138.809998  180.169998  136.850006  181.990005  138.352005
# ...

# %%
price2.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close', 'GOOG'),
#             (    'Close', 'AAPL'),
#             (    'Close', 'GOOG'),
#             (     'High', 'AAPL'),
#             (     'High', 'GOOG'),
#             (      'Low', 'AAPL'),
#             (      'Low', 'GOOG'),
#             (     'Open', 'AAPL'),
#             (     'Open', 'GOOG'),
#             (   'Volume', 'AAPL'),
#             (   'Volume', 'GOOG')],
#            )

# %%
price2['Close']['AAPL']
# Out:
# Date
# 2024-01-02    185.639999
# 2024-01-03    184.250000
# 2024-01-04    181.910004
# 2024-01-05    181.179993
# 2024-01-08    185.559998
#                  ...
# 2024-08-01    218.360001
# 2024-08-02    219.860001
# 2024-08-05    209.270004
# 2024-08-06    207.229996
# 2024-08-07    209.820007
# Name: AAPL, Length: 151, dtype: float64

# %%
close1 = price2['Adj Close']
close1.head()
# Out:
#                   AAPL        GOOG
# Date
# 2024-01-02  185.152283  139.401367
# 2024-01-03  183.765930  140.200455
# 2024-01-04  181.432098  137.883087
# 2024-01-05  180.703995  137.233841
# 2024-01-08  185.072495  140.370270

# %%
(183.765930 - 185.152283) / 185.152283
# Out:
# -0.007487636541862213

# %%
percentage = close1.pct_change()
percentage.head()
# Out:
#                 AAPL      GOOG
# Date
# 2024-01-02       NaN       NaN
# 2024-01-03 -0.007488  0.005732
# 2024-01-04 -0.012700 -0.016529
# 2024-01-05 -0.004013 -0.004709
# 2024-01-08  0.024175  0.022855

# %%
percentage.plot(figsize = (12,7), lw = 2)

plt.grid()
plt.xlabel('Date', fontsize=14, fontname = "Times New Roman")
plt.ylabel('Percentage', fontsize=14, fontname = "Times New Roman")
plt.title("Google and Apple Percentages in Price", fontsize=16, fontname = "Times New Roman")

plt.legend(fontsize=10)

plt.show()

# %%
price2['Adj Close'].pct_change().plot(figsize = (12,7), lw = 2)

plt.grid()
plt.xlabel('Date', fontsize=14, fontname = "Times New Roman")
plt.ylabel('Percentage', fontsize=14, fontname = "Times New Roman")
plt.title("Google Percentages in Price", fontsize=16, fontname = "Times New Roman")

plt.legend(fontsize=10)

plt.show()

# %%
close1.head()
# Out:
#                   AAPL        GOOG
# Date
# 2024-01-02  185.152283  139.401367
# 2024-01-03  183.765930  140.200455
# 2024-01-04  181.432098  137.883087
# 2024-01-05  180.703995  137.233841
# 2024-01-08  185.072495  140.370270

# %%
183.765930 - 185.152283
# Out:
# -1.386353000000014

# %%
difference = close1.diff()
difference.head()
# Out:
#                 AAPL      GOOG
# Date
# 2024-01-02       NaN       NaN
# 2024-01-03 -1.386353  0.799088
# 2024-01-04 -2.333832 -2.317368
# 2024-01-05 -0.728104 -0.649246
# 2024-01-08  4.368500  3.136429

# %%
difference.plot(figsize = (12,7), lw = 2)

plt.grid()
plt.xlabel('Date', fontsize=14, fontname = "Times New Roman")
plt.ylabel('Percentage', fontsize=14, fontname = "Times New Roman")
plt.title("Google and Apple difference daily Price", fontsize=16, fontname = "Times New Roman")

plt.legend(fontsize=10)

plt.show()

# %%
price['Adj Close']
# Out:
# Date
# 2024-01-02    139.401367
# 2024-01-03    140.200455
# 2024-01-04    137.883087
# 2024-01-05    137.233841
# 2024-01-08    140.370270
#                  ...
# 2024-08-01    172.449997
# 2024-08-02    168.399994
# 2024-08-05    160.639999
# 2024-08-06    160.539993
# 2024-08-07    160.750000
# Name: Adj Close, Length: 151, dtype: float64

# %%
price['Adj Close'].shift(1)
# Out:
# Date
# 2024-01-02           NaN
# 2024-01-03    139.401367
# 2024-01-04    140.200455
# 2024-01-05    137.883087
# 2024-01-08    137.233841
#                  ...
# 2024-08-01    173.149994
# 2024-08-02    172.449997
# 2024-08-05    168.399994
# 2024-08-06    160.639999
# 2024-08-07    160.539993
# Name: Adj Close, Length: 151, dtype: float64

# %%
price['Lg_returns'] = np.log(price['Adj Close'] / price['Adj Close'].shift(1))
price.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-02  139.600006  140.615005  137.740005  139.559998  139.401367
# 2024-01-03  138.600006  141.089996  138.429993  140.360001  140.200455
# 2024-01-04  139.850006  140.634995  138.009995  138.039993  137.883087
# 2024-01-05  138.352005  138.809998  136.850006  137.389999  137.233841
# 2024-01-08  138.000000  140.639999  137.880005  140.529999  140.370270
#
#               Volume  Lg_returns
# Date
# 2024-01-02  20071900         NaN
# 2024-01-03  18974300    0.005716
# 2024-01-04  18253300   -0.016667
# 2024-01-05  15433200   -0.004720
# 2024-01-08  17645300    0.022597

# %%
price['Adj Close'].rolling(10).mean().head(15)
# Out:
# Date
# 2024-01-02           NaN
# 2024-01-03           NaN
# 2024-01-04           NaN
# 2024-01-05           NaN
# 2024-01-08           NaN
# 2024-01-09           NaN
# 2024-01-10           NaN
# 2024-01-11           NaN
# 2024-01-12           NaN
# 2024-01-16    141.262250
# 2024-01-17    141.594872
# 2024-01-18    142.057346
# 2024-01-19    143.049217
# 2024-01-22    144.080045
# 2024-01-23    144.894118
# Name: Adj Close, dtype: float64

# %%
price['MA10'] = price['Adj Close'].rolling(10).mean()
price.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-08-01  171.979996  175.679993  170.509995  172.449997  172.449997
# 2024-08-02  168.190002  170.210007  166.389999  168.399994  168.399994
# 2024-08-05  157.369995  165.940002  156.600006  160.639999  160.639999
# 2024-08-06  160.945007  162.350006  158.130005  160.539993  160.539993
# 2024-08-07  163.240005  164.789993  160.240005  160.750000  160.750000
#
#               Volume  Lg_returns        MA10
# Date
# 2024-08-01  17177800   -0.004051  174.714000
# 2024-08-02  18907800   -0.023765  173.614999
# 2024-08-05  34907800   -0.047176  171.343999
# 2024-08-06  36146500   -0.000623  169.037997
# 2024-08-07  19288800    0.001307  167.675998

# %%
price['MA10'] = price['Adj Close'].rolling(10).mean()

plt.figure(figsize=(12,8))
plt.plot(price.index, price['Adj Close'], lw = 2, c = 'b', label='Adj Close Price')
plt.plot(price.index, price['MA10'], lw = 2, c = 'r', label='Rolling Average (10)')

plt.legend()
plt.grid()
plt.show()

# %%
price['diff'] = price.High - price.Low
price.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-02  139.600006  140.615005  137.740005  139.559998  139.401367
# 2024-01-03  138.600006  141.089996  138.429993  140.360001  140.200455
# 2024-01-04  139.850006  140.634995  138.009995  138.039993  137.883087
# 2024-01-05  138.352005  138.809998  136.850006  137.389999  137.233841
# 2024-01-08  138.000000  140.639999  137.880005  140.529999  140.370270
#
#               Volume  Lg_returns  MA10      diff
# Date
# 2024-01-02  20071900         NaN   NaN  2.875000
# 2024-01-03  18974300    0.005716   NaN  2.660004
# 2024-01-04  18253300   -0.016667   NaN  2.625000
# 2024-01-05  15433200   -0.004720   NaN  1.959991
# 2024-01-08  17645300    0.022597   NaN  2.759995

# %%
price[['diff', 'Volume']].corr()
# Out:
#             diff    Volume
# diff    1.000000  0.416201
# Volume  0.416201  1.000000

# %% [markdown]
# | Symbols | Company |
# |---      | ---     |
# |INTC| Intel|
# |MSFT| Microsoft|
# |IBM| IBM|
# |BHP| BHP|
# |TM| Toyota|
# |AAPL| Apple|
# |AMZN| Amazon|
# |BA| Boeing|
# |QCOM| Qualcomm|
# |KO| Coca-Cola|
# |GOOG| Google|
# |SNE| Sony|
# |PTR| PetroChina|
# |NVDA | NVIDIA|

# %% [markdown]
# ### 2.2 data reader

# %% [markdown]
# | Symbols | Company |
# |---      | ---     |
# |INTC| Intel|
# |MSFT| Microsoft|
# |IBM| IBM|
# |BHP| BHP|
# |TM| Toyota|
# |AAPL| Apple|
# |AMZN| Amazon|
# |BA| Boeing|
# |QCOM| Qualcomm|
# |KO| Coca-Cola|
# |GOOG| Google|
# |SNE| Sony|
# |PTR| PetroChina|

# %% [markdown]
# ## 3. Extra Work

# %%
price_AAPL = data.DataReader('AAPL', start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
price_AAPL.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-02  187.149994  188.440002  183.889999  185.639999  185.152283
# 2024-01-03  184.220001  185.880005  183.429993  184.250000  183.765930
# 2024-01-04  182.149994  183.089996  180.880005  181.910004  181.432098
# 2024-01-05  181.990005  182.759995  180.169998  181.179993  180.703995
# 2024-01-08  182.089996  185.600006  181.500000  185.559998  185.072495
#
#               Volume
# Date
# 2024-01-02  82488700
# 2024-01-03  58414500
# 2024-01-04  71983600
# 2024-01-05  62303300
# 2024-01-08  59144500

# %%
price_AAPL['daily_diffrence'] = price_AAPL['Adj Close'].diff()
price_AAPL.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-02  187.149994  188.440002  183.889999  185.639999  185.152283
# 2024-01-03  184.220001  185.880005  183.429993  184.250000  183.765930
# 2024-01-04  182.149994  183.089996  180.880005  181.910004  181.432098
# 2024-01-05  181.990005  182.759995  180.169998  181.179993  180.703995
# 2024-01-08  182.089996  185.600006  181.500000  185.559998  185.072495
#
#               Volume  daily_diffrence
# Date
# 2024-01-02  82488700              NaN
# 2024-01-03  58414500        -1.386353
# 2024-01-04  71983600        -2.333832
# 2024-01-05  62303300        -0.728104
# 2024-01-08  59144500         4.368500

# %%
price_AAPL['signal'] = np.where(price_AAPL['daily_diffrence'] > 0, 1, 0)
price_AAPL.head(10)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-02  187.149994  188.440002  183.889999  185.639999  185.152283
# 2024-01-03  184.220001  185.880005  183.429993  184.250000  183.765930
# 2024-01-04  182.149994  183.089996  180.880005  181.910004  181.432098
# 2024-01-05  181.990005  182.759995  180.169998  181.179993  180.703995
# 2024-01-08  182.089996  185.600006  181.500000  185.559998  185.072495
# 2024-01-09  183.919998  185.149994  182.729996  185.139999  184.653595
# 2024-01-10  184.350006  186.399994  183.919998  186.190002  185.700851
# 2024-01-11  186.539993  187.050003  183.619995  185.589996  185.102417
# 2024-01-12  186.059998  186.740005  185.190002  185.919998  185.431549
# 2024-01-16  182.160004  184.259995  180.929993  183.630005  183.147568
#
#               Volume  daily_diffrence  signal
# Date
# 2024-01-02  82488700              NaN       0
# 2024-01-03  58414500        -1.386353       0
# ...

# %%
price_AAPL['position'] = price_AAPL['signal'].diff()
price_AAPL.head(10)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-02  187.149994  188.440002  183.889999  185.639999  185.152283
# 2024-01-03  184.220001  185.880005  183.429993  184.250000  183.765930
# 2024-01-04  182.149994  183.089996  180.880005  181.910004  181.432098
# 2024-01-05  181.990005  182.759995  180.169998  181.179993  180.703995
# 2024-01-08  182.089996  185.600006  181.500000  185.559998  185.072495
# 2024-01-09  183.919998  185.149994  182.729996  185.139999  184.653595
# 2024-01-10  184.350006  186.399994  183.919998  186.190002  185.700851
# 2024-01-11  186.539993  187.050003  183.619995  185.589996  185.102417
# 2024-01-12  186.059998  186.740005  185.190002  185.919998  185.431549
# 2024-01-16  182.160004  184.259995  180.929993  183.630005  183.147568
#
#               Volume  daily_diffrence  signal  position
# Date
# 2024-01-02  82488700              NaN       0       NaN
# 2024-01-03  58414500        -1.386353       0       0.0
# ...

# %%
price_AAPL[price_AAPL['position'] == 1.0].index
# Out:
# DatetimeIndex(['2024-01-08', '2024-01-10', '2024-01-12', '2024-01-18',
#                '2024-02-01', '2024-02-05', '2024-02-09', '2024-02-21',
#                '2024-02-27', '2024-03-08', '2024-03-14', '2024-03-18',
#                '2024-03-22', '2024-03-27', '2024-04-03', '2024-04-05',
#                '2024-04-09', '2024-04-11', '2024-04-22', '2024-04-29',
#                '2024-05-02', '2024-05-07', '2024-05-13', '2024-05-24',
#                '2024-06-07', '2024-06-11', '2024-06-17', '2024-06-24',
#                '2024-07-01', '2024-07-12', '2024-07-19', '2024-07-23',
#                '2024-07-26', '2024-08-02', '2024-08-07'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
price_AAPL[price_AAPL['position'] == 1.0]['Adj Close']
# Out:
# Date
# 2024-01-08    185.072495
# 2024-01-10    185.700851
# 2024-01-12    185.431549
# 2024-01-18    188.134430
# 2024-02-01    186.369095
# 2024-02-05    187.186920
# 2024-02-09    188.594208
# 2024-02-21    182.073059
# 2024-02-27    182.382629
# 2024-03-08    170.498734
# 2024-03-14    172.765671
# 2024-03-18    173.484695
# 2024-03-22    172.046646
# 2024-03-27    173.075241
# 2024-04-03    169.420197
# 2024-04-05    169.350296
# 2024-04-09    169.440170
# 2024-04-11    174.802902
# 2024-04-22    165.615356
# 2024-04-29    173.264984
# 2024-05-02    172.795624
# 2024-05-07    182.152924
# 2024-05-13    186.279999
# 2024-05-24    189.979996
# 2024-06-07    196.889999
# 2024-06-11    207.149994
# 2024-06-17    216.669998
# 2024-06-24    208.139999
# 2024-07-01    216.750000
# 2024-07-12    230.539993
# 2024-07-19    224.309998
# 2024-07-23    225.009995
# 2024-07-26    217.960007
# 2024-08-02    219.860001
# 2024-08-07    209.820007
# Name: Adj Close, dtype: float64

# %%
plt.figure(figsize=(12,7))

plt.plot(price_AAPL['Adj Close'], c = 'r', lw = 2)
plt.plot(price_AAPL[price_AAPL['position'] == 1.0].index,
        price_AAPL[price_AAPL['position'] == 1.0]['Adj Close'], 'o', c='g', markersize = 7
        )

plt.plot(price_AAPL[price_AAPL['position'] == -1.0].index,
        price_AAPL[price_AAPL['position'] == -1.0]['Adj Close'], 'x', c='k', markersize = 7
        )

plt.grid()
plt.show()

# %% [markdown]
# ## 4. World Bank

# %% [markdown]
# ### 4.1 Imports

# %%
#from pandas_datareader import wb
#import wbdata as wb

# %%
import wbgapi as wb

# %%
wb.source.info()
wb.time.info()
wb.region.info()
wb.economy.info()
# Out:
# id    value                                                 region    incomeLevel
# ----  ----------------------------------------------------  --------  -------------
# ABW   Aruba                                                 LCN       HIC
# AFE   Africa Eastern and Southern
# AFG   Afghanistan                                           SAS       LIC
# AFW   Africa Western and Central
# AGO   Angola                                                SSF       LMC
# ALB   Albania                                               ECS       UMC
# AND   Andorra                                               ECS       HIC
# ARB   Arab World
# ARE   United Arab Emirates                                  MEA       HIC
# ARG   Argentina                                             LCN       UMC
# ARM   Armenia                                               ECS       UMC
# ASM   American Samoa                                        EAS       HIC
# ...

# %%
wb.region.members('MNA')
# Out:
# {'DJI',
#  'DZA',
#  'EGY',
#  'IRN',
#  'IRQ',
#  'JOR',
#  'LBN',
#  'LBY',
#  'MAR',
#  'PSE',
#  'SYR',
#  'TUN',
#  'YEM'}

# %%
inf = wb.data.DataFrame(series='FP.CPI.TOTL.ZG',
                       economy='all',
                       time='all', numericTimeKeys=True,
                       labels=True) # for show countries name
inf.head()
# Out:
#                        Country  1960  1961  1962  1963  1964  1965  1966  \
# economy
# ZWE                   Zimbabwe   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ZMB                     Zambia   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# YEM                Yemen, Rep.   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# PSE         West Bank and Gaza   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# VIR      Virgin Islands (U.S.)   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#          1967  1968  ...      2014       2015       2016      2017       2018  \
# economy              ...
# ZWE       NaN   NaN  ... -0.197785  -2.430968  -1.543670  0.893962  10.618866
# ZMB       NaN   NaN  ...  7.806876  10.110593  17.869730  6.577312   7.494572
# YEM       NaN   NaN  ...  8.104726        NaN        NaN       NaN        NaN
# PSE       NaN   NaN  ...  1.732985   1.431611  -0.219107  0.212571  -0.195108
# VIR       NaN   NaN  ...       NaN        NaN        NaN       NaN        NaN
#
# ...

# %%
inf2 = inf.set_index('Country').sort_index()
inf2.head()
# Out:
#                              1960  1961  1962  1963  1964  1965  1966  1967  \
# Country
# Afghanistan                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Africa Eastern and Southern   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Africa Western and Central    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Algeria                       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                              1968  1969  ...      2014      2015      2016  \
# Country                                  ...
# Afghanistan                   NaN   NaN  ...  4.673996 -0.661709  4.383892
# Africa Eastern and Southern   NaN   NaN  ...  5.370290  5.245878  6.571396
# Africa Western and Central    NaN   NaN  ...  1.768436  2.130817  1.487416
# Albania                       NaN   NaN  ...  1.625865  1.896174  1.275432
# Algeria                       NaN   NaN  ...  2.916927  4.784447  6.397695
#
# ...

# %%
inf3 = inf2.T
inf3.head()
# Out:
# Country  Afghanistan  Africa Eastern and Southern  Africa Western and Central  \
# 1960             NaN                          NaN                         NaN
# 1961             NaN                          NaN                         NaN
# 1962             NaN                          NaN                         NaN
# 1963             NaN                          NaN                         NaN
# 1964             NaN                          NaN                         NaN
#
# Country  Albania  Algeria  American Samoa  Andorra  Angola  \
# 1960         NaN      NaN             NaN      NaN     NaN
# 1961         NaN      NaN             NaN      NaN     NaN
# 1962         NaN      NaN             NaN      NaN     NaN
# 1963         NaN      NaN             NaN      NaN     NaN
# 1964         NaN      NaN             NaN      NaN     NaN
#
# Country  Antigua and Barbuda  Arab World  ...  Uzbekistan  Vanuatu  \
# 1960                     NaN         NaN  ...         NaN      NaN
# ...

# %%
inf3['Iran, Islamic Rep.'].plot(figsize = (12,7), lw=2)

plt.grid()

plt.legend()
plt.show()

# %%
inf3[['Iran, Islamic Rep.', 'China']].plot(figsize = (12,7), lw=2)

plt.grid()

plt.legend()
plt.show()

# %%
wb.data.DataFrame('FP.CPI.TOTL.ZG',
                 economy=wb.region.members('MNA'),
                 time='all', numericTimeKeys=True,
                 labels=True).set_index('Country').T.plot(figsize=(12,7), lw = 2)

plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [142], line 1
# ----> 1 wb.data.DataFrame('FP.CPI.TOTL.ZG',
#       2                  economy=wb.region.members('MNA'),
#       3                  time='all', numericTimeKeys=True,
#       4                  labels=True).set_index('Country').T.plot(figsize=(12,7), lw = 2)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/wbgapi/data.py:334, in DataFrame(series, economy, time, index, columns, mrv, mrnev, skipBlanks, labels, skipAggs, numericTimeKeys, timeColumns, params, db, **dimensions)
#     330 if labels:
#     331     # create a separate dataframe for labels so that we can control the column position below
#     332     df2 = frame(index)
# ...

# %% [markdown]
# ## 5. Statemodel

# %% [markdown]
# ## 5.1

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
price.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-02  139.600006  140.615005  137.740005  139.559998  139.401367
# 2024-01-03  138.600006  141.089996  138.429993  140.360001  140.200455
# 2024-01-04  139.850006  140.634995  138.009995  138.039993  137.883087
# 2024-01-05  138.352005  138.809998  136.850006  137.389999  137.233841
# 2024-01-08  138.000000  140.639999  137.880005  140.529999  140.370270
#
#               Volume  Lg_returns  MA10      diff
# Date
# 2024-01-02  20071900         NaN   NaN  2.875000
# 2024-01-03  18974300    0.005716   NaN  2.660004
# 2024-01-04  18253300   -0.016667   NaN  2.625000
# 2024-01-05  15433200   -0.004720   NaN  1.959991
# 2024-01-08  17645300    0.022597   NaN  2.759995

# %%
y = price['Volume']
X = price['Adj Close']

X = sm.add_constant(X)

# %%
model = sm.OLS(y,X).fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Volume   R-squared:                       0.113
# Model:                            OLS   Adj. R-squared:                  0.107
# Method:                 Least Squares   F-statistic:                     18.92
# Date:                Thu, 08 Aug 2024   Prob (F-statistic):           2.52e-05
# Time:                        10:36:51   Log-Likelihood:                -2611.2
# No. Observations:                 151   AIC:                             5226.
# Df Residuals:                     149   BIC:                             5232.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.793e+07    6.3e+06      7.610      0.000    3.55e+07    6.04e+07
# ...

# %% [markdown]
# ## 5.2

# %%
data = pd.read_csv('/Users/saeed/Library/CloudStorage/OneDrive-DalhousieUniversity/Dalhousie University - Saeed/Summer 2024/International Trade/Paper/merged_data.csv')

# %%
data.head()
# Out:
#   Country Code  Year      R&D  TradeOpen           GDP
# 0          ARG  2000  0.43884  22.622445  3.956461e+11
# 1          ARM  2000  0.19106  72.233330  3.959425e+09
# 2          AUS  2000  1.57320  40.935211  8.726338e+11
# 3          AUT  2000  1.88602  85.360496  3.111924e+11
# 4          AZE  2000  0.33600  78.548568  1.191844e+10

# %%
data.rename(columns={"Country Code":'Country_Code', "R&D":"RD"}, inplace=True)

# %%
data.head()
# Out:
#   Country_Code  Year       RD  TradeOpen           GDP
# 0          ARG  2000  0.43884  22.622445  3.956461e+11
# 1          ARM  2000  0.19106  72.233330  3.959425e+09
# 2          AUS  2000  1.57320  40.935211  8.726338e+11
# 3          AUT  2000  1.88602  85.360496  3.111924e+11
# 4          AZE  2000  0.33600  78.548568  1.191844e+10

# %%
formula = 'RD ~ TradeOpen + GDP'

model = smf.ols(formula, data = data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     RD   R-squared:                       0.138
# Model:                            OLS   Adj. R-squared:                  0.138
# Method:                 Least Squares   F-statistic:                     193.6
# Date:                Thu, 08 Aug 2024   Prob (F-statistic):           1.09e-78
# Time:                        10:50:54   Log-Likelihood:                -3076.8
# No. Observations:                2413   AIC:                             6160.
# Df Residuals:                    2410   BIC:                             6177.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.8437      0.033     25.539      0.000       0.779       0.908
# ...

# %%
formula = 'RD ~ TradeOpen + GDP + C(Country_Code) + C(Year)'

model = smf.ols(formula, data = data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     RD   R-squared:                       0.960
# Model:                            OLS   Adj. R-squared:                  0.960
# Method:                 Least Squares   F-statistic:                 2.886e+04
# Date:                Thu, 08 Aug 2024   Prob (F-statistic):               0.00
# Time:                        10:52:18   Log-Likelihood:                 624.62
# No. Observations:                2413   AIC:                            -1243.
# Df Residuals:                    2410   BIC:                            -1226.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.5151      0.031     16.619      0.000       0.454       0.576
# ...
