# %% [markdown]
# # <center> Project 01: Covid19 Data Analysis<br> ---------------------------------------------- <center>

# %% [markdown]
# ### Let's Import the modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.listdir()
# Out:
# ['time_series_covid19_confirmed_global.csv',
#  '5. Matplotlib.ipynb',
#  'survey_results_public.csv',
#  'world-happiness-report-2021.csv',
#  '.DS_Store',
#  'P_Data_Extract_From_World_Development_Indicators.xlsx',
#  'Project 01 - Covid19 confirmed cases.ipynb',
#  'Iran_gdp_growth.jpg',
#  '1. Introduction to Python (Data Structure).ipynb',
#  'GDP per capita ppp 2021.xlsx',
#  'Real GDP Growth (IMF).xlsx',
#  '3. Functions.ipynb',
#  'Py for Econ-Intro-Tehran Workshop 2024.pdf',
#  '6. Pandas 01.ipynb',
#  '2. Control flow (Loops).ipynb',
#  '7. Pandas 02.ipynb',
#  'Human development index (HDI).xlsx',
#  '.ipynb_checkpoints',
#  'test_1.jpg',
#  'data',
#  '8. Pandas 03.ipynb',
#  '4. NumPy.ipynb']

# %% [markdown]
# ## Task 1

# %% [markdown]
# ### Task 1.1: importing covid19 dataset

# %%
corona_dataset = pd.read_csv('time_series_covid19_confirmed_global.csv')
corona_dataset.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  2/28/23  3/1/23  3/2/23  3/3/23  \
# 0        0        0        0        0  ...   209322  209340  209358  209362
# 1        0        0        0        0  ...   334391  334408  334408  334427
# 2        0        0        0        0  ...   271441  271448  271463  271469
# 3        0        0        0        0  ...    47866   47875   47875   47875
# 4        0        0        0        0  ...   105255  105277  105277  105277
#
#    3/4/23  3/5/23  3/6/23  3/7/23  3/8/23  3/9/23
# 0  209369  209390  209406  209436  209451  209451
# 1  334427  334427  334427  334427  334443  334457
# 2  271469  271477  271477  271490  271494  271496
# 3   47875   47875   47875   47875   47890   47890
# 4  105277  105277  105277  105277  105288  105288
#
# [5 rows x 1147 columns]

# %% [markdown]
# #### Let's check the shape of the dataframe

# %%
corona_dataset.shape
# Out:
# (289, 1147)

# %% [markdown]
# ### Task 1.2: Delete the useless columns

# %%
corona_dataset.drop(['Lat', "Long"], axis = 1, inplace=True)

# %%
corona_dataset.head(15)
# Out:
#                   Province/State       Country/Region  1/22/20  1/23/20  \
# 0                            NaN          Afghanistan        0        0
# 1                            NaN              Albania        0        0
# 2                            NaN              Algeria        0        0
# 3                            NaN              Andorra        0        0
# 4                            NaN               Angola        0        0
# 5                            NaN           Antarctica        0        0
# 6                            NaN  Antigua and Barbuda        0        0
# 7                            NaN            Argentina        0        0
# 8                            NaN              Armenia        0        0
# 9   Australian Capital Territory            Australia        0        0
# 10               New South Wales            Australia        0        0
# 11            Northern Territory            Australia        0        0
# 12                    Queensland            Australia        0        0
# 13               South Australia            Australia        0        0
# 14                      Tasmania            Australia        0        0
#
#     1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  ...   2/28/23  \
# 0         0        0        0        0        0        0  ...    209322
# 1         0        0        0        0        0        0  ...    334391
# 2         0        0        0        0        0        0  ...    271441
# 3         0        0        0        0        0        0  ...     47866
# 4         0        0        0        0        0        0  ...    105255
# 5         0        0        0        0        0        0  ...        11
# 6         0        0        0        0        0        0  ...      9106
# 7         0        0        0        0        0        0  ...  10044125
# 8         0        0        0        0        0        0  ...    446819
# 9         0        0        0        0        0        0  ...    232018
# 10        0        0        3        4        4        4  ...   3900969
# 11        0        0        0        0        0        0  ...    104931
# 12        0        0        0        0        0        1  ...   1796633
# 13        0        0        0        0        0        0  ...    880207
# 14        0        0        0        0        0        0  ...    286264
#
#       3/1/23    3/2/23    3/3/23    3/4/23    3/5/23    3/6/23    3/7/23  \
# 0     209340    209358    209362    209369    209390    209406    209436
# 1     334408    334408    334427    334427    334427    334427    334427
# 2     271448    271463    271469    271469    271477    271477    271490
# 3      47875     47875     47875     47875     47875     47875     47875
# 4     105277    105277    105277    105277    105277    105277    105277
# 5         11        11        11        11        11        11        11
# 6       9106      9106      9106      9106      9106      9106      9106
# 7   10044125  10044125  10044125  10044125  10044125  10044957  10044957
# 8     446819    446819    446819    446819    446819    446819    446819
# 9     232018    232619    232619    232619    232619    232619    232619
# 10   3900969   3908129   3908129   3908129   3908129   3908129   3908129
# 11    104931    105021    105021    105021    105021    105021    105021
# 12   1796633   1800236   1800236   1800236   1800236   1800236   1800236
# 13    880207    881911    881911    881911    881911    881911    881911
# 14    286264    286264    286897    286897    286897    286897    286897
#
#       3/8/23    3/9/23
# 0     209451    209451
# 1     334443    334457
# 2     271494    271496
# 3      47890     47890
# 4     105288    105288
# 5         11        11
# 6       9106      9106
# 7   10044957  10044957
# 8     447308    447308
# 9     232619    232974
# 10   3908129   3915992
# 11    105021    105111
# 12   1800236   1800236
# 13    881911    883620
# 14    286897    287507
#
# [15 rows x 1145 columns]

# %% [markdown]
# ### Task 1.3: Aggregating the rows by the country

# %%
corona_dataset_aggregated = corona_dataset.groupby('Country/Region').sum(numeric_only=True)
corona_dataset_aggregated.head(15)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antarctica                 0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
# Azerbaijan                 0        0        0        0        0        0
# Bahamas                    0        0        0        0        0        0
# Bahrain                    0        0        0        0        0        0
# Bangladesh                 0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20  ...   2/28/23  \
# Country/Region                                           ...
# Afghanistan                0        0        0        0  ...    209322
# Albania                    0        0        0        0  ...    334391
# Algeria                    0        0        0        0  ...    271441
# Andorra                    0        0        0        0  ...     47866
# Angola                     0        0        0        0  ...    105255
# Antarctica                 0        0        0        0  ...        11
# Antigua and Barbuda        0        0        0        0  ...      9106
# Argentina                  0        0        0        0  ...  10044125
# Armenia                    0        0        0        0  ...    446819
# Australia                  5        6        9        9  ...  11366361
# Austria                    0        0        0        0  ...   5911294
# Azerbaijan                 0        0        0        0  ...    828548
# Bahamas                    0        0        0        0  ...     37491
# Bahrain                    0        0        0        0  ...    707480
# Bangladesh                 0        0        0        0  ...   2037773
#
#                        3/1/23    3/2/23    3/3/23    3/4/23    3/5/23  \
# Country/Region
# Afghanistan            209340    209358    209362    209369    209390
# Albania                334408    334408    334427    334427    334427
# Algeria                271448    271463    271469    271469    271477
# Andorra                 47875     47875     47875     47875     47875
# Angola                 105277    105277    105277    105277    105277
# Antarctica                 11        11        11        11        11
# Antigua and Barbuda      9106      9106      9106      9106      9106
# Argentina            10044125  10044125  10044125  10044125  10044125
# Armenia                446819    446819    446819    446819    446819
# Australia            11366361  11384901  11385534  11385534  11385534
# Austria               5919616   5926148   5931247   5936666   5940935
# Azerbaijan             828588    828628    828648    828682    828721
# Bahamas                 37491     37491     37491     37491     37491
# Bahrain                707828    708061    708532    708768    709230
# Bangladesh            2037829   2037829   2037829   2037829   2037829
#
#                        3/6/23    3/7/23    3/8/23    3/9/23
# Country/Region
# Afghanistan            209406    209436    209451    209451
# Albania                334427    334427    334443    334457
# Algeria                271477    271490    271494    271496
# Andorra                 47875     47875     47890     47890
# Angola                 105277    105277    105288    105288
# Antarctica                 11        11        11        11
# Antigua and Barbuda      9106      9106      9106      9106
# Argentina            10044957  10044957  10044957  10044957
# Armenia                446819    446819    447308    447308
# Australia            11385534  11385534  11385534  11399460
# Austria               5943417   5949418   5955860   5961143
# Azerbaijan             828730    828783    828819    828825
# Bahamas                 37491     37491     37491     37491
# Bahrain                709230    709858    710306    710693
# Bangladesh            2037829   2037829   2037871   2037871
#
# [15 rows x 1143 columns]

# %%
corona_dataset_aggregated.shape
# Out:
# (201, 1143)

# %% [markdown]
# ### Task 1.4: Visualizing data related to countries (for example China, Italy, Spain and Iran)

# %%
plt.figure(figsize =(9,5))
corona_dataset_aggregated.loc['China'].plot(lw = 2)
corona_dataset_aggregated.loc['Italy'].plot(lw = 2)
corona_dataset_aggregated.loc['Spain'].plot(lw = 2)
corona_dataset_aggregated.loc['Iran'].plot(lw = 2)

plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize =(9,5))
plt.plot(range(0,1143), corona_dataset_aggregated.loc['China'], label='China')
plt.plot(range(0,1143), corona_dataset_aggregated.loc['Italy'], label='Italy')
plt.plot(range(0,1143), corona_dataset_aggregated.loc['Spain'], label='Spain')
plt.plot(range(0,1143), corona_dataset_aggregated.loc['Iran'], label='Iran')

plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(2,2,1)
plt.bar(range(0,1143), corona_dataset_aggregated.loc['China'], color = 'r', label='China')
plt.grid()
plt.legend()

plt.subplot(2,2,2)
plt.bar(range(0,1143), corona_dataset_aggregated.loc['Italy'], color = 'b', label='Italy')
plt.grid()
plt.legend()

plt.subplot(2,2,3)
plt.bar(range(0,1143), corona_dataset_aggregated.loc['Spain'], color = 'g', label='Spain')
plt.grid()
plt.legend()

plt.subplot(2,2,4)
plt.bar(range(0,1143), corona_dataset_aggregated.loc['Iran'], color = 'm', label='Iran')
plt.grid()
plt.legend()

plt.show()

# %% [markdown]
# ## Task 2: Calculating a good measure

# %%
corona_dataset_aggregated.loc['China'].plot()
# Out:
# <AxesSubplot:>

# %%
corona_dataset_aggregated.loc['China'][:3].plot()
# Out:
# <AxesSubplot:>

# %%
corona_dataset_aggregated.loc['Iran'][15:].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### task 2.1: caculating the first derivative of the curve (for China and Italy and Iran)

# %%
corona_dataset_aggregated.loc['China'].diff().plot()
# Out:
# <AxesSubplot:>

# %%
corona_dataset_aggregated.loc['Iran'].diff().plot()
# Out:
# <AxesSubplot:>

# %%
corona_dataset_aggregated.loc['Italy'].diff().plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### task 2.2: find maxmimum infection rate

# %%
corona_dataset_aggregated.loc['China'].diff().max()
# Out:
# 78859.0

# %%
corona_dataset_aggregated.loc['Iran'].diff().max()
# Out:
# 50228.0

# %%
corona_dataset_aggregated.loc['Italy'].diff().max()
# Out:
# 229122.0

# %% [markdown]
# ### Task 2.3: find maximum infection rate for all of the countries.

# %%
corona_dataset_aggregated.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Antarctica',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia',
#        ...
#        'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela', 'Vietnam',
#        'West Bank and Gaza', 'Winter Olympics 2022', 'Yemen', 'Zambia',
#        'Zimbabwe'],
#       dtype='object', name='Country/Region', length=201)

# %%
country = list(corona_dataset_aggregated.index)

# %%
#country

# %%
max_infection = []

for c in country:
    max_infection.append(corona_dataset_aggregated.loc[c].diff().max())

# %%
corona_dataset_aggregated['max_infection_rate'] = max_infection

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  3/1/23  3/2/23  3/3/23  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...  209340  209358  209362
# Albania               0        0        0  ...  334408  334408  334427
# Algeria               0        0        0  ...  271448  271463  271469
# Andorra               0        0        0  ...   47875   47875   47875
# Angola                0        0        0  ...  105277  105277  105277
#
#                 3/4/23  3/5/23  3/6/23  3/7/23  3/8/23  3/9/23  \
# Country/Region
# Afghanistan     209369  209390  209406  209436  209451  209451
# Albania         334427  334427  334427  334427  334443  334457
# Algeria         271469  271477  271477  271490  271494  271496
# Andorra          47875   47875   47875   47875   47890   47890
# Angola          105277  105277  105277  105277  105288  105288
#
#                 max_infection_rate
# Country/Region
# Afghanistan                 3243.0
# Albania                     4789.0
# Algeria                     2521.0
# Andorra                     2313.0
# Angola                      5035.0
#
# [5 rows x 1144 columns]

# %% [markdown]
# ### Task 2.4: create a new dataframe with only needed column

# %%
corona_2 = pd.DataFrame(corona_dataset_aggregated['max_infection_rate'])
corona_2.head()
# Out:
#                 max_infection_rate
# Country/Region
# Afghanistan                 3243.0
# Albania                     4789.0
# Algeria                     2521.0
# Andorra                     2313.0
# Angola                      5035.0

# %%
#corona_2 = corona_dataset_aggregated['max_infection_rate']

# %% [markdown]
# ### Task 3:
# - <b>Importing the WorldHappinessReport.csv dataset<b>
# - <b>selecting needed columns for our analysis <b>
# - <b>join the datasets <b>

# %% [markdown]
# ### Task 3.1 : importing the dataset

# %%
os.listdir()
# Out:
# ['time_series_covid19_confirmed_global.csv',
#  '5. Matplotlib.ipynb',
#  'survey_results_public.csv',
#  'world-happiness-report-2021.csv',
#  '.DS_Store',
#  'P_Data_Extract_From_World_Development_Indicators.xlsx',
#  'Project 01 - Covid19 confirmed cases.ipynb',
#  'Iran_gdp_growth.jpg',
#  '1. Introduction to Python (Data Structure).ipynb',
#  'GDP per capita ppp 2021.xlsx',
#  'Real GDP Growth (IMF).xlsx',
#  '3. Functions.ipynb',
#  'Py for Econ-Intro-Tehran Workshop 2024.pdf',
#  '6. Pandas 01.ipynb',
#  '2. Control flow (Loops).ipynb',
#  '7. Pandas 02.ipynb',
#  'Human development index (HDI).xlsx',
#  '.ipynb_checkpoints',
#  'test_1.jpg',
#  'data',
#  '8. Pandas 03.ipynb',
#  '4. NumPy.ipynb']

# %%
happiness_report = pd.read_csv('world-happiness-report-2021.csv')
happiness_report.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# 3                 10.878           0.983                     73.0
# 4                 10.932           0.942                     72.4
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.949      -0.098                      0.186
# 1                         0.946       0.030                      0.179
# 2                         0.919       0.025                      0.292
# 3                         0.955       0.160                      0.673
# 4                         0.913       0.175                      0.338
#
#    Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                      2.43                             1.446
# 1                      2.43                             1.502
# 2                      2.43                             1.566
# 3                      2.43                             1.482
# 4                      2.43                             1.501
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.106                                  0.741
# 1                         1.108                                  0.763
# 2                         1.079                                  0.816
# 3                         1.172                                  0.772
# 4                         1.079                                  0.753
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       0.691                     0.124
# 1                                       0.686                     0.208
# 2                                       0.653                     0.204
# 3                                       0.698                     0.293
# 4                                       0.647                     0.302
#
#    Explained by: Perceptions of corruption  Dystopia + residual
# 0                                    0.481                3.253
# 1                                    0.485                2.868
# 2                                    0.413                2.839
# 3                                    0.170                2.967
# 4                                    0.384                2.798

# %%
happiness_report.shape
# Out:
# (149, 20)

# %%
#happiness_report['Country name'].unique()

# %% [markdown]
# ### Task 3.2: let's drop the useless columns

# %%
happiness_report.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
useless = [
    'Regional indicator',
    'Standard error of ladder score',
    'upperwhisker', 'lowerwhisker',
    'Ladder score in Dystopia',
    'Explained by: Log GDP per capita', 'Explained by: Social support',
    'Explained by: Healthy life expectancy',
    'Explained by: Freedom to make life choices',
    'Explained by: Generosity', 'Explained by: Perceptions of corruption',
    'Dystopia + residual'
]

# %%
happiness_report.drop(useless, axis = 1, inplace=True)

# %%
happiness_report.head()
# Out:
#   Country name  Ladder score  Logged GDP per capita  Social support  \
# 0      Finland         7.842                 10.775           0.954
# 1      Denmark         7.620                 10.933           0.954
# 2  Switzerland         7.571                 11.117           0.942
# 3      Iceland         7.554                 10.878           0.983
# 4  Netherlands         7.464                 10.932           0.942
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                     72.0                         0.949      -0.098
# 1                     72.7                         0.946       0.030
# 2                     74.4                         0.919       0.025
# 3                     73.0                         0.955       0.160
# 4                     72.4                         0.913       0.175
#
#    Perceptions of corruption
# 0                      0.186
# 1                      0.179
# 2                      0.292
# 3                      0.673
# 4                      0.338

# %% [markdown]
# ### Task 3.3: changing the indices of the dataframe

# %%
happiness_report.set_index('Country name', inplace=True)

# %%
happiness_report.head()
# Out:
#               Ladder score  Logged GDP per capita  Social support  \
# Country name
# Finland              7.842                 10.775           0.954
# Denmark              7.620                 10.933           0.954
# Switzerland          7.571                 11.117           0.942
# Iceland              7.554                 10.878           0.983
# Netherlands          7.464                 10.932           0.942
#
#               Healthy life expectancy  Freedom to make life choices  \
# Country name
# Finland                          72.0                         0.949
# Denmark                          72.7                         0.946
# Switzerland                      74.4                         0.919
# Iceland                          73.0                         0.955
# Netherlands                      72.4                         0.913
#
#               Generosity  Perceptions of corruption
# Country name
# Finland           -0.098                      0.186
# Denmark            0.030                      0.179
# Switzerland        0.025                      0.292
# Iceland            0.160                      0.673
# Netherlands        0.175                      0.338

# %% [markdown]
# ### Task 3.4: now let's join two dataset we have prepared

# %% [markdown]
# #### Corona Dataset :

# %%
corona_2.head()
# Out:
#                 max_infection_rate
# Country/Region
# Afghanistan                 3243.0
# Albania                     4789.0
# Algeria                     2521.0
# Andorra                     2313.0
# Angola                      5035.0

# %%
corona_2.shape
# Out:
# (201, 1)

# %% [markdown]
# #### world happiness report Dataset :

# %%
happiness_report.head()
# Out:
#               Ladder score  Logged GDP per capita  Social support  \
# Country name
# Finland              7.842                 10.775           0.954
# Denmark              7.620                 10.933           0.954
# Switzerland          7.571                 11.117           0.942
# Iceland              7.554                 10.878           0.983
# Netherlands          7.464                 10.932           0.942
#
#               Healthy life expectancy  Freedom to make life choices  \
# Country name
# Finland                          72.0                         0.949
# Denmark                          72.7                         0.946
# Switzerland                      74.4                         0.919
# Iceland                          73.0                         0.955
# Netherlands                      72.4                         0.913
#
#               Generosity  Perceptions of corruption
# Country name
# Finland           -0.098                      0.186
# Denmark            0.030                      0.179
# Switzerland        0.025                      0.292
# Iceland            0.160                      0.673
# Netherlands        0.175                      0.338

# %%
happiness_report.shape
# Out:
# (149, 7)

# %% [markdown]
# #### Join

# %%
data = corona_2.join(happiness_report, how='inner')
data.head()
# Out:
#              max_infection_rate  Ladder score  Logged GDP per capita  \
# Afghanistan              3243.0         2.523                  7.695
# Albania                  4789.0         5.117                  9.520
# Algeria                  2521.0         4.887                  9.342
# Argentina              139853.0         5.929                  9.962
# Armenia                  4388.0         5.283                  9.487
#
#              Social support  Healthy life expectancy  \
# Afghanistan           0.463                   52.493
# Albania               0.697                   68.999
# Algeria               0.802                   66.005
# Argentina             0.898                   69.000
# Armenia               0.799                   67.055
#
#              Freedom to make life choices  Generosity  \
# Afghanistan                         0.382      -0.102
# Albania                             0.785      -0.030
# Algeria                             0.480      -0.067
# Argentina                           0.828      -0.182
# Armenia                             0.825      -0.168
#
#              Perceptions of corruption
# Afghanistan                      0.924
# Albania                          0.901
# Algeria                          0.752
# Argentina                        0.834
# Armenia                          0.629

# %%
data.shape
# Out:
# (138, 8)

# %% [markdown]
# ## Task 4: calculate the correlations as the result of our analysis

# %% [markdown]
# ### Task 4.1: correlation matrix

# %%
data.corr()
# Out:
#                               max_infection_rate  Ladder score  \
# max_infection_rate                      1.000000      0.255588
# Ladder score                            0.255588      1.000000
# Logged GDP per capita                   0.322941      0.794891
# Social support                          0.236806      0.771801
# Healthy life expectancy                 0.344605      0.791496
# Freedom to make life choices            0.052039      0.620936
# Generosity                             -0.037978      0.005967
# Perceptions of corruption              -0.165432     -0.444626
#
#                               Logged GDP per capita  Social support  \
# max_infection_rate                         0.322941        0.236806
# Ladder score                               0.794891        0.771801
# Logged GDP per capita                      1.000000        0.798452
# Social support                             0.798452        1.000000
# Healthy life expectancy                    0.872090        0.748850
# Freedom to make life choices               0.456510        0.486266
# Generosity                                -0.213038       -0.136501
# Perceptions of corruption                 -0.342169       -0.221934
#
#                               Healthy life expectancy  \
# max_infection_rate                           0.344605
# Ladder score                                 0.791496
# Logged GDP per capita                        0.872090
# Social support                               0.748850
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.493911
# Generosity                                  -0.176480
# Perceptions of corruption                   -0.365988
#
#                               Freedom to make life choices  Generosity  \
# max_infection_rate                                0.052039   -0.037978
# Ladder score                                      0.620936    0.005967
# Logged GDP per capita                             0.456510   -0.213038
# Social support                                    0.486266   -0.136501
# Healthy life expectancy                           0.493911   -0.176480
# Freedom to make life choices                      1.000000    0.139830
# Generosity                                        0.139830    1.000000
# Perceptions of corruption                        -0.427770   -0.164040
#
#                               Perceptions of corruption
# max_infection_rate                            -0.165432
# Ladder score                                  -0.444626
# Logged GDP per capita                         -0.342169
# Social support                                -0.221934
# Healthy life expectancy                       -0.365988
# Freedom to make life choices                  -0.427770
# Generosity                                    -0.164040
# Perceptions of corruption                      1.000000

# %% [markdown]
# #### Correlation more than 0.5

# %%
data.corr()[data.corr()>0.5]
# Out:
#                               max_infection_rate  Ladder score  \
# max_infection_rate                           1.0           NaN
# Ladder score                                 NaN      1.000000
# Logged GDP per capita                        NaN      0.794891
# Social support                               NaN      0.771801
# Healthy life expectancy                      NaN      0.791496
# Freedom to make life choices                 NaN      0.620936
# Generosity                                   NaN           NaN
# Perceptions of corruption                    NaN           NaN
#
#                               Logged GDP per capita  Social support  \
# max_infection_rate                              NaN             NaN
# Ladder score                               0.794891        0.771801
# Logged GDP per capita                      1.000000        0.798452
# Social support                             0.798452        1.000000
# Healthy life expectancy                    0.872090        0.748850
# Freedom to make life choices                    NaN             NaN
# Generosity                                      NaN             NaN
# Perceptions of corruption                       NaN             NaN
#
#                               Healthy life expectancy  \
# max_infection_rate                                NaN
# Ladder score                                 0.791496
# Logged GDP per capita                        0.872090
# Social support                               0.748850
# Healthy life expectancy                      1.000000
# Freedom to make life choices                      NaN
# Generosity                                        NaN
# Perceptions of corruption                         NaN
#
#                               Freedom to make life choices  Generosity  \
# max_infection_rate                                     NaN         NaN
# Ladder score                                      0.620936         NaN
# Logged GDP per capita                                  NaN         NaN
# Social support                                         NaN         NaN
# Healthy life expectancy                                NaN         NaN
# Freedom to make life choices                      1.000000         NaN
# Generosity                                             NaN         1.0
# Perceptions of corruption                              NaN         NaN
#
#                               Perceptions of corruption
# max_infection_rate                                  NaN
# Ladder score                                        NaN
# Logged GDP per capita                               NaN
# Social support                                      NaN
# Healthy life expectancy                             NaN
# Freedom to make life choices                        NaN
# Generosity                                          NaN
# Perceptions of corruption                           1.0

# %%
data.corr()[data.corr()>0.3]
# Out:
#                               max_infection_rate  Ladder score  \
# max_infection_rate                      1.000000           NaN
# Ladder score                                 NaN      1.000000
# Logged GDP per capita                   0.322941      0.794891
# Social support                               NaN      0.771801
# Healthy life expectancy                 0.344605      0.791496
# Freedom to make life choices                 NaN      0.620936
# Generosity                                   NaN           NaN
# Perceptions of corruption                    NaN           NaN
#
#                               Logged GDP per capita  Social support  \
# max_infection_rate                         0.322941             NaN
# Ladder score                               0.794891        0.771801
# Logged GDP per capita                      1.000000        0.798452
# Social support                             0.798452        1.000000
# Healthy life expectancy                    0.872090        0.748850
# Freedom to make life choices               0.456510        0.486266
# Generosity                                      NaN             NaN
# Perceptions of corruption                       NaN             NaN
#
#                               Healthy life expectancy  \
# max_infection_rate                           0.344605
# Ladder score                                 0.791496
# Logged GDP per capita                        0.872090
# Social support                               0.748850
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.493911
# Generosity                                        NaN
# Perceptions of corruption                         NaN
#
#                               Freedom to make life choices  Generosity  \
# max_infection_rate                                     NaN         NaN
# Ladder score                                      0.620936         NaN
# Logged GDP per capita                             0.456510         NaN
# Social support                                    0.486266         NaN
# Healthy life expectancy                           0.493911         NaN
# Freedom to make life choices                      1.000000         NaN
# Generosity                                             NaN         1.0
# Perceptions of corruption                              NaN         NaN
#
#                               Perceptions of corruption
# max_infection_rate                                  NaN
# Ladder score                                        NaN
# Logged GDP per capita                               NaN
# Social support                                      NaN
# Healthy life expectancy                             NaN
# Freedom to make life choices                        NaN
# Generosity                                          NaN
# Perceptions of corruption                           1.0

# %% [markdown]
# ### Task 5: Visualization of the results

# %%
data.head()
# Out:
#              max_infection_rate  Ladder score  Logged GDP per capita  \
# Afghanistan              3243.0         2.523                  7.695
# Albania                  4789.0         5.117                  9.520
# Algeria                  2521.0         4.887                  9.342
# Argentina              139853.0         5.929                  9.962
# Armenia                  4388.0         5.283                  9.487
#
#              Social support  Healthy life expectancy  \
# Afghanistan           0.463                   52.493
# Albania               0.697                   68.999
# Algeria               0.802                   66.005
# Argentina             0.898                   69.000
# Armenia               0.799                   67.055
#
#              Freedom to make life choices  Generosity  \
# Afghanistan                         0.382      -0.102
# Albania                             0.785      -0.030
# Algeria                             0.480      -0.067
# Argentina                           0.828      -0.182
# Armenia                             0.825      -0.168
#
#              Perceptions of corruption
# Afghanistan                      0.924
# Albania                          0.901
# Algeria                          0.752
# Argentina                        0.834
# Armenia                          0.629

# %% [markdown]
# ### Task 5.1: Plotting GDP vs maximum Infection rate

# %%
x = data['Logged GDP per capita']
y = data['max_infection_rate']

sns.scatterplot(x =x , y = np.log(y))
# Out:
# <AxesSubplot:xlabel='Logged GDP per capita', ylabel='max_infection_rate'>

# %%
plt.figure(figsize=(9,6))
sns.regplot(x =x, y = np.log(y))
plt.title('GDP per Capita VS Max infection rate', fontsize=15, fontname='Times New Roman')

plt.grid()
plt.show()

# %% [markdown]
# ### Task 5.2: Plotting Social support vs maximum Infection rate

# %%
x = data['Social support']
y = data['max_infection_rate']

sns.scatterplot(x =x , y = np.log(y))

plt.figure(figsize=(9,6))
sns.regplot(x =x, y = np.log(y))
plt.title('Social Support VS Max infection rate', fontsize=15, fontname='Times New Roman')

plt.grid()
plt.show()

# %% [markdown]
# ### Task 5.3: Plotting Healthy life expectancy vs maximum Infection rate

# %%
x = data['Healthy life expectancy']
y = data['max_infection_rate']

sns.scatterplot(x =x , y = np.log(y))

plt.figure(figsize=(9,6))
sns.regplot(x =x, y = np.log(y))
plt.title('Healthy life expectancy VS Max infection rate', fontsize=15, fontname='Times New Roman')

plt.grid()
plt.show()

# %% [markdown]
# ### Task 5.4: Plotting Freedom to make life choices vs maximum Infection rate

# %%
x = data['Freedom to make life choices']
y = data['max_infection_rate']

sns.scatterplot(x =x , y = np.log(y))

plt.figure(figsize=(9,6))
sns.regplot(x =x, y = np.log(y))
plt.title('Freedom to make life choices VS Max infection rate', fontsize=15, fontname='Times New Roman')

plt.grid()
plt.show()

# %%
x = data['Ladder score']
y = data['max_infection_rate']

sns.scatterplot(x =x , y = np.log(y))

plt.figure(figsize=(9,6))
sns.regplot(x =x, y = np.log(y))
plt.title('Ladder score VS Max infection rate', fontsize=15, fontname='Times New Roman')

plt.grid()
plt.show()
